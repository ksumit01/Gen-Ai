# %%
1=='1'

# %%
# %run '/Users/sumit/Documents/GA201/D4-PyhtonD2/Mumbai-Munchies-L1/main.py'
# Out:
# *** Snack Inventory Management ***
# 1. Add Snack
# 2. Remove Snack
# 3. Update Snack
# 4. View Snack Inventory
# 5. Make Sell
# 6. View Sale Records
# 7. Exit
# Enter your choice (1/2/3/4): 1
#
# === Add Snack to Inventory ===
# Enter Snack Name You Want To Add: Samosa
# Enter the Price of the Snack: 12
# Enter Total Quantity of the Snacks: 12
#
# Snack added successfully!
#
# Updated Inventory:
# ID: 1
# Name: Samosa
# Price: ₹12.00
# Quantity: 12
# Available: Yes
# ------------------------------
#
# *** Snack Inventory Management ***
# 1. Add Snack
# 2. Remove Snack
# 3. Update Snack
# 4. View Snack Inventory
# 5. Make Sell
# 6. View Sale Records
# 7. Exit
# Enter your choice (1/2/3/4): 1
#
# === Add Snack to Inventory ===
# Enter Snack Name You Want To Add: Cookies
# Enter the Price of the Snack: 20
# Enter Total Quantity of the Snacks: 10
#
# Snack added successfully!
#
# Updated Inventory:
# ID: 1
# Name: Samosa
# Price: ₹12.00
# Quantity: 12
# Available: Yes
# ...
